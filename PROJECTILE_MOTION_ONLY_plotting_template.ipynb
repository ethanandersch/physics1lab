# %% [markdown]
# <a href="https://colab.research.google.com/github/ethanandersch/physics1lab/blob/main/PROJECTILE_MOTION_ONLY_plotting_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PHSX 216 Projectile Motion Lab plotting code
#performs 2nd degree polynomial fit
#Brianna Beller
#Updated September 2024

import numpy as np
import matplotlib.pyplot as plt

#-----------------------------------------------------------------------#
#----------UPDATE THIS SECTION!!!----------

#DATA TO BE PLOTTED
#UPDATE THE VARIABLE NAMES & NUMBERS (LEAVE BRACKETS/PARENTHESES AS IS)
#variable names should start with a letter and must contain only letters, numbers, and underscores

Angle = np.array([43, 40, 46, 37, 49]) #what are units?   <-----

Height = np.array([0.7708, 0.8116, 0.7594, 0.7638, 0.637]) #what are units?   <-----

err_Height = np.array([0.005, 0.005, 0.005, 0.005, 0.005,])                   #                 <-----

#Re-assign variables as x, y, dy so that the remaining plotting code may remain generic
#UPDATE VARIABLE NAMES (ON RHS OF EACH EQUAL SIGN) TO MATCH VARIABLE NAMES FOR DATA ABOVE

x = Angle             #this should be the array you want to plot on the x axis #        <-----
y = Height             #this should be the array you want to plot on the y axis #        <-----
dy = err_Height        #this should be your error in y array                    #        <-----

#UPDATE EACH OF THESE 3 STRINGS FOR YOUR PLOT LABELS AS YOU WANT THEM TO APPEAR

plot_title= 'Angle vs Height'                                                                #                 <-----
x_label= 'Angle [Degrees]'                                                    #                 <-----
y_label= 'Height [Meters]'                                                    #                 <-----

#-----------------------------------------------------------------------#
#-----DON'T NEED TO CHANGE ANYTHING BEYOND THIS POINT!!!-----


#size the plot
plt.figure(figsize=(15,10))

#create scatter plot
plt.scatter(x, y, color='blue', marker='o')

#create labels
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)

#fitting to a 2nd degree polynomial
c,b,a=np.polynomial.polynomial.polyfit(x,y,2,w=dy)

#Annotate with values of A, B, C from best fit polynomial
plt.annotate('best fit line: $f(x)=Ax^2+Bx+C$',(0.05, 0.95), xycoords='axes fraction')

plt.annotate('     A = {:.3f}'.format(a),(0.05, 0.9), xycoords='axes fraction')

plt.annotate('     B = {:.3f}'.format(b),(0.05, 0.85), xycoords='axes fraction')

plt.annotate('     C = {:.3f}'.format(c),(0.05, 0.8), xycoords='axes fraction')

#Create fit line
xnew = np.linspace(x.min(), x.max(), 300)
fit = a*xnew**2 + b*xnew +c

plt.plot(xnew, fit, color='green')
plt.show()
